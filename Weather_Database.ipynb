# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# import the citipy to find the near cities with lat and lot
from citipy import citipy
# import the requests module
import requests
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the time module.
import time
# Import the API key.
from config import weather_api_key

# %%
# use the numpy to generate the uniform random 1500 items
# latutude is -90 and 90 ( equator 0 to the northern end 90 and reversely equator 0 to southern end 90)
lats = np.random.uniform(-90,90,1500)
# longitude is -180 to 180 ( Meridian 0 (GreenSwitch Mean Time (GMT) to Eastern end 180 and to Western 180)
lons = np.random.uniform(-180,180,1500)
# zip function of Python native to create tuple pairs. zip is temporary memory. it will be destroyed after unzip like list
locations = list(zip(lats,lons))

# %%
#Use the citipy.nearest_city to find a city with (lat,lon) tuple
#list conrehensive to populate the list
#need to get the unique city names
cities = [citipy.nearest_city(lat,lon).city_name for lat,lon in locations]
cities = np.unique(cities)
len(cities)
# Out:
# 623

# %%
#use OpenWeather Api to retrieve info
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# function retrieve weather info return a dictionary of the city weather info or NONE
def retrieve_weather_info(index, city_name):
    # query by city name is used &q=city_name
    url_city = f"{url}&q={city_name}"
    city_dict = {}
    print(f"Retrieve {index}::{city_name.upper()} data")
    # open weather is not covered all locations on earth so it may give code 404
    try:
        #if the request successful, convert response data back to json (python dictionary).
        city_weather = requests.get(url_city).json()
        #success code == 200                  
        if city_weather["cod"] == 200:
            city_dict["City"] = city_weather["name"]
            city_dict["Country"] = city_weather["sys"]["country"]
            # Convert the date to ISO standard.
            city_dict["Date"] = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            city_dict["Lat"] = city_weather["coord"]["lat"]
            city_dict["Lng"] = city_weather["coord"]["lon"]
            city_dict["Max Temp"] = city_weather["main"]["temp_max"]
            city_dict["Humidity"] = city_weather["main"]["humidity"]
            city_dict["Cloudiness"] = city_weather["clouds"]["all"]
            city_dict["Wind Speed"] = city_weather["wind"]["speed"]
            city_dict["Current Description"] = city_weather["weather"][0]["description"]

            #weather phenomena are not always happened, so the data may present or not
            #Rain inches in last 3 hours
            try:
                city_dict["Rain inches(last 3hrs)"] = city_weather["rain"]["3h"]
            except:
                city_dict["Rain inches(last 3hrs)"] = 0
            #Snow inches in last 3 hours
            try:
                city_dict["Snow inches(last 3hrs)"] = city_weather["snow"]["3h"]
            except:
                city_dict["Snow inches(last 3hrs)"] = 0

            # return the dict of the city weather info
            return city_dict
        else:
            print(f"{city_name} could not found weather info <Error>")
    except:
       print(f"OpenWeather API were down<Error>")
    return None

# Create an empty list to hold the weather data.
city_data = []
# loop through all cities
for i,city_name in enumerate(cities):
    city_weather_info = retrieve_weather_info(i, city_name)
    if city_weather_info:
        #add the city weather info in the city data list
        city_data.append(city_weather_info)

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
len(city_data)
# Out:
# Retrieve 0::ABONG MBANG data
# Retrieve 1::ABONNEMA data
# Retrieve 2::ABU DHABI data
# Retrieve 3::ACARAU data
# Retrieve 4::ACHACACHI data
# Retrieve 5::AFLU data
# aflu could not found weather info <Error>
# Retrieve 6::AFSIN data
# Retrieve 7::AHIPARA data
# Retrieve 8::AIRAI data
# Retrieve 9::AKLAVIK data
# Retrieve 10::ALBANY data
# Retrieve 11::ALLENDE data
# Retrieve 12::ALLISTON data
# Retrieve 13::ALOFI data
# Retrieve 14::AMBILOBE data
# Retrieve 15::AMDERMA data
# amderma could not found weather info <Error>
# Retrieve 16::AMOT data
# Retrieve 17::ANACONDA data
# Retrieve 18::ANADYR data
# Retrieve 19::ANCHORAGE data
# Retrieve 20::ANCUD data
# Retrieve 21::AQUIRAZ data
# Retrieve 22::ARINOS data
# Retrieve 23::ARIPUANA data
# Retrieve 24::ARRAIAL DO CABO data
# Retrieve 25::ARRIFES data
# Retrieve 26::ASAU data
# Retrieve 27::AT-BASHI data
# Retrieve 28::ATAMBUA data
# Retrieve 29::ATBASAR data
# Retrieve 30::ATTAWAPISKAT data
# attawapiskat could not found weather info <Error>
# Retrieve 31::ATUNTAQUI data
# Retrieve 32::ATUONA data
# Retrieve 33::AUKI data
# Retrieve 34::AVARUA data
# Retrieve 35::AVERA data
# Retrieve 36::AZIMUR data
# azimur could not found weather info <Error>
# Retrieve 37::BABOUA data
# baboua could not found weather info <Error>
# Retrieve 38::BACUIT data
# bacuit could not found weather info <Error>
# Retrieve 39::BALAIPUNGUT data
# Retrieve 40::BALLINA data
# Retrieve 41::BAMBOUS VIRIEUX data
# Retrieve 42::BANDARBEYLA data
# Retrieve 43::BARAWE data
# barawe could not found weather info <Error>
# Retrieve 44::BARENTSBURG data
# barentsburg could not found weather info <Error>
# Retrieve 45::BARENTU data
# Retrieve 46::BARROW data
# Retrieve 47::BATAGAY data
# Retrieve 48::BATAGAY-ALYTA data
# Retrieve 49::BATEMANS BAY data
# Retrieve 50::BATHSHEBA data
# Retrieve 51::BATTICALOA data
# Retrieve 52::BAY CITY data
# Retrieve 53::BAYKIT data
# Retrieve 54::BEIDAO data
# Retrieve 55::BEINAMAR data
# Retrieve 56::BELOHA data
# Retrieve 57::BELUSHYA GUBA data
# belushya guba could not found weather info <Error>
# Retrieve 58::BENGHAZI data
# Retrieve 59::BENGKULU data
# Retrieve 60::BERINGOVSKIY data
# Retrieve 61::BERLEVAG data
# Retrieve 62::BETHEL data
# Retrieve 63::BILIBINO data
# Retrieve 64::BILMA data
# Retrieve 65::BIMA data
# Retrieve 66::BIRIN data
# Retrieve 67::BIRJAND data
# Retrieve 68::BIZHBULYAK data
# Retrieve 69::BLUFF data
# Retrieve 70::BOA VISTA data
# Retrieve 71::BOCARANGA data
# bocaranga could not found weather info <Error>
# Retrieve 72::BODEN data
# Retrieve 73::BOLUNGARVIK data
# bolungarvik could not found weather info <Error>
# Retrieve 74::BONAVISTA data
# Retrieve 75::BORBA data
# Retrieve 76::BREDASDORP data
# Retrieve 77::BROOME data
# Retrieve 78::BUALA data
# Retrieve 79::BUD data
# Retrieve 80::BULGAN data
# Retrieve 81::BULUNGU data
# Retrieve 82::BURNS LAKE data
# Retrieve 83::BUSINGA data
# Retrieve 84::BUSSELTON data
# Retrieve 85::BUTARITARI data
# Retrieve 86::CA MAU data
# Retrieve 87::CABATUAN data
# Retrieve 88::CABEDELO data
# Retrieve 89::CABO SAN LUCAS data
# Retrieve 90::CABRA data
# Retrieve 91::CAMANA data
# Retrieve 92::CAMPBELLTON data
# Retrieve 93::CAPE TOWN data
# Retrieve 94::CARAVELAS data
# Retrieve 95::CARIAMANGA data
# Retrieve 96::CARNARVON data
# Retrieve 97::CARNOT data
# Retrieve 98::CARTAGENA data
# Retrieve 99::CASTRO data
# Retrieve 100::CAYENNE data
# Retrieve 101::CELESTUN data
# Retrieve 102::CHAGDA data
# chagda could not found weather info <Error>
# Retrieve 103::CHAKE CHAKE data
# Retrieve 104::CHANY data
# Retrieve 105::CHAPLEAU data
# Retrieve 106::CHARTERS TOWERS data
# Retrieve 107::CHERNYSHEVSKIY data
# Retrieve 108::CHERSKIY data
# Retrieve 109::CHOKURDAKH data
# Retrieve 110::CHONGOYAPE data
# Retrieve 111::CHRISTCHURCH data
# Retrieve 112::CHUMIKAN data
# Retrieve 113::CHUY data
# Retrieve 114::CIDREIRA data
# Retrieve 115::CLYDE RIVER data
# Retrieve 116::COARI data
# Retrieve 117::CODAJAS data
# Retrieve 118::CODRINGTON data
# Retrieve 119::COIHAIQUE data
# Retrieve 120::COLLEGE data
# Retrieve 121::COMODORO RIVADAVIA data
# Retrieve 122::CONSTITUCION data
# Retrieve 123::CONTAI data
# Retrieve 124::COOLUM BEACH data
# Retrieve 125::COOS BAY data
# Retrieve 126::COPACABANA data
# Retrieve 127::CORINTO data
# Retrieve 128::COZUMEL data
# Retrieve 129::CRAVO NORTE data
# Retrieve 130::DABOLA data
# Retrieve 131::DAKAR data
# Retrieve 132::DARU data
# Retrieve 133::DENPASAR data
# Retrieve 134::DEPUTATSKIY data
# Retrieve 135::DERA DIN PANAH data
# dera din panah could not found weather info <Error>
# Retrieve 136::DEZHOU data
# Retrieve 137::DHIDHDHOO data
# Retrieve 138::DHING data
# Retrieve 139::DICKINSON data
# Retrieve 140::DIFFA data
# Retrieve 141::DIKSON data
# Retrieve 142::DINGLE data
# Retrieve 143::DIRE data
# Retrieve 144::DJENNE data
# Retrieve 145::DRUMHELLER data
# Retrieve 146::DUBBO data
# Retrieve 147::DUGNA data
# dugna could not found weather info <Error>
# Retrieve 148::DWARKA data
# Retrieve 149::DZHUSALY data
# dzhusaly could not found weather info <Error>
# Retrieve 150::EAST LONDON data
# Retrieve 151::EDD data
# Retrieve 152::EGVEKINOT data
# Retrieve 153::ENDIREY data
# Retrieve 154::ENTEBBE data
# Retrieve 155::ESPERANCE data
# Retrieve 156::ESSEX data
# Retrieve 157::EWA BEACH data
# Retrieve 158::FAANUI data
# Retrieve 159::FAIRBANKS data
# Retrieve 160::FARAFANGANA data
# Retrieve 161::FENOARIVO data
# Retrieve 162::FEVRALSK data
# fevralsk could not found weather info <Error>
# Retrieve 163::FLIN FLON data
# Retrieve 164::FLINDERS data
# Retrieve 165::FORTUNA data
# Retrieve 166::GAMBA data
# Retrieve 167::GAT data
# Retrieve 168::GEORGE data
# Retrieve 169::GEORGETOWN data
# Retrieve 170::GERALDTON data
# Retrieve 171::GILGIL data
# gilgil could not found weather info <Error>
# Retrieve 172::GILLETTE data
# Retrieve 173::GLENDIVE data
# Retrieve 174::GODERICH data
# Retrieve 175::GOLYSHMANOVO data
# Retrieve 176::GORNYY data
# Retrieve 177::GOUNDI data
# Retrieve 178::GRAND RIVER SOUTH EAST data
# grand river south east could not found weather info <Error>
# Retrieve 179::GRAVDAL data
# Retrieve 180::GRINDAVIK data
# Retrieve 181::GUAMUCHIL data
# Retrieve 182::GUERRERO NEGRO data
# Retrieve 183::GUSAU data
# Retrieve 184::GZHATSK data
# gzhatsk could not found weather info <Error>
# Retrieve 185::HALALO data
# halalo could not found weather info <Error>
# Retrieve 186::HALF MOON BAY data
# Retrieve 187::HALIFAX data
# Retrieve 188::HAMBANTOTA data
# Retrieve 189::HAMI data
# Retrieve 190::HAMILTON data
# Retrieve 191::HAMMERFEST data
# Retrieve 192::HAMZA data
# Retrieve 193::HARPER data
# Retrieve 194::HASAKI data
# Retrieve 195::HASTINGS data
# Retrieve 196::HAVOYSUND data
# Retrieve 197::HAVRE-SAINT-PIERRE data
# Retrieve 198::HENTIES BAY data
# Retrieve 199::HERMANUS data
# Retrieve 200::HERVEY BAY data
# Retrieve 201::HIHIFO data
# hihifo could not found weather info <Error>
# Retrieve 202::HILO data
# Retrieve 203::HIROSHIMA data
# Retrieve 204::HITHADHOO data
# Retrieve 205::HLUTI data
# Retrieve 206::HOBART data
# Retrieve 207::HOBYO data
# Retrieve 208::HOFN data
# Retrieve 209::HUALMAY data
# Retrieve 210::HUANREN data
# Retrieve 211::HUARMEY data
# Retrieve 212::HUILONG data
# Retrieve 213::HURGHADA data
# Retrieve 214::HUSAVIK data
# Retrieve 215::IDAR-OBERSTEIN data
# Retrieve 216::IGRIM data
# Retrieve 217::ILLOQQORTOORMIUT data
# illoqqortoormiut could not found weather info <Error>
# Retrieve 218::ILULISSAT data
# Retrieve 219::IQALUIT data
# Retrieve 220::IRACOUBO data
# Retrieve 221::ISANGEL data
# Retrieve 222::ISTOK data
# Retrieve 223::ITOMAN data
# Retrieve 224::IXTAPA data
# Retrieve 225::JALU data
# Retrieve 226::JAMESTOWN data
# Retrieve 227::JIANGYOU data
# Retrieve 228::JINCHANG data
# Retrieve 229::JIZAN data
# Retrieve 230::JOIGNY data
# Retrieve 231::JUTAI data
# Retrieve 232::KABALO data
# Retrieve 233::KABINDA data
# Retrieve 234::KAFANCHAN data
# Retrieve 235::KAHULUI data
# Retrieve 236::KAITANGATA data
# Retrieve 237::KAMAISHI data
# Retrieve 238::KAMENKA data
# Retrieve 239::KAMENSKOYE data
# kamenskoye could not found weather info <Error>
# Retrieve 240::KANDE data
# Retrieve 241::KANNIYAKUMARI data
# Retrieve 242::KAPAA data
# Retrieve 243::KARAUL data
# karaul could not found weather info <Error>
# Retrieve 244::KARGASOK data
# Retrieve 245::KATHU data
# Retrieve 246::KATTIVAKKAM data
# Retrieve 247::KAVARATTI data
# Retrieve 248::KAVIENG data
# Retrieve 249::KAWALU data
# Retrieve 250::KAZALINSK data
# kazalinsk could not found weather info <Error>
# Retrieve 251::KEDROVYY data
# Retrieve 252::KERMAN data
# Retrieve 253::KETI BANDAR data
# Retrieve 254::KHANI data
# Retrieve 255::KHATANGA data
# Retrieve 256::KIDAL data
# Retrieve 257::KIRANDO data
# Retrieve 258::KIUNGA data
# Retrieve 259::KLAKSVIK data
# Retrieve 260::KLOULKLUBED data
# Retrieve 261::KODIAK data
# Retrieve 262::KOLDA data
# Retrieve 263::KORLA data
# Retrieve 264::KORSAKOVO data
# Retrieve 265::KOZMODEMYANSK data
# Retrieve 266::KRALENDIJK data
# Retrieve 267::KRASNOOKTYABRSKIY data
# Retrieve 268::KRASNOSELKUP data
# Retrieve 269::KRASNOVKA data
# Retrieve 270::KRUISFONTEIN data
# Retrieve 271::KUAH data
# Retrieve 272::KUNUNURRA data
# Retrieve 273::KURILSK data
# Retrieve 274::KURUMKAN data
# Retrieve 275::KURYK data
# Retrieve 276::LA RIOJA data
# Retrieve 277::LA RONGE data
# Retrieve 278::LABUHAN data
# Retrieve 279::LAGOA data
# Retrieve 280::LAGUNA data
# Retrieve 281::LANGHAM data
# Retrieve 282::LASA data
# Retrieve 283::LAUNCESTON data
# Retrieve 284::LAVRENTIYA data
# Retrieve 285::LEBU data
# Retrieve 286::LEETON data
# Retrieve 287::LENINGRADSKIY data
# Retrieve 288::LETHEM data
# Retrieve 289::LIMON data
# Retrieve 290::LINARES data
# Retrieve 291::LINDI data
# Retrieve 292::LOLUA data
# lolua could not found weather info <Error>
# Retrieve 293::LOMPOC data
# Retrieve 294::LONGYEARBYEN data
# Retrieve 295::LOUISBOURG data
# louisbourg could not found weather info <Error>
# Retrieve 296::LUANDA data
# Retrieve 297::LUDERITZ data
# Retrieve 298::LUENA data
# Retrieve 299::LUKOVETSKIY data
# Retrieve 300::LUYANG data
# Retrieve 301::MACABOBONI data
# macaboboni could not found weather info <Error>
# Retrieve 302::MACKAY data
# Retrieve 303::MACKENZIE data
# Retrieve 304::MADANG data
# Retrieve 305::MAHEBOURG data
# Retrieve 306::MAHON data
# Retrieve 307::MAKAKILO CITY data
# Retrieve 308::MAKSATIKHA data
# Retrieve 309::MALWAN data
# malwan could not found weather info <Error>
# Retrieve 310::MANDAN data
# Retrieve 311::MANDURAH data
# Retrieve 312::MANSA data
# Retrieve 313::MAR DEL PLATA data
# Retrieve 314::MARAGOGI data
# Retrieve 315::MARAWI data
# Retrieve 316::MARCONA data
# marcona could not found weather info <Error>
# Retrieve 317::MAREEBA data
# Retrieve 318::MARGATE data
# Retrieve 319::MARIGOT data
# Retrieve 320::MARSA MATRUH data
# Retrieve 321::MARSABIT data
# Retrieve 322::MASUGURU data
# Retrieve 323::MATADI data
# Retrieve 324::MATAURA data
# Retrieve 325::MAYO data
# Retrieve 326::MAYOR PABLO LAGERENZA data
# Retrieve 327::MBUJI-MAYI data
# Retrieve 328::MECCA data
# Retrieve 329::MERAUKE data
# Retrieve 330::MERCEDES data
# Retrieve 331::METRO data
# Retrieve 332::MEYUNGS data
# meyungs could not found weather info <Error>
# Retrieve 333::MIDDLE ISLAND data
# Retrieve 334::MILDURA data
# Retrieve 335::MISRATAH data
# Retrieve 336::MITSAMIOULI data
# Retrieve 337::MITU data
# Retrieve 338::MIZAN TEFERI data
# Retrieve 339::MOCAMBIQUE data
# mocambique could not found weather info <Error>
# Retrieve 340::MOCUBA data
# Retrieve 341::MOGOCHIN data
# mogochin could not found weather info <Error>
# Retrieve 342::MORON data
# Retrieve 343::MORONDAVA data
# Retrieve 344::MOUNT ISA data
# Retrieve 345::MUDYUGA data
# mudyuga could not found weather info <Error>
# Retrieve 346::MUGUMU data
# Retrieve 347::MUNDO NUEVO data
# Retrieve 348::MUROTO data
# Retrieve 349::MURUPARA data
# Retrieve 350::MUTSAMUDU data
# mutsamudu could not found weather info <Error>
# Retrieve 351::MUZAFFARABAD data
# Retrieve 352::MVUMA data
# Retrieve 353::MYS SHMIDTA data
# mys shmidta could not found weather info <Error>
# Retrieve 354::NADOR data
# Retrieve 355::NAMATANAI data
# Retrieve 356::NAMIBE data
# Retrieve 357::NANORTALIK data
# Retrieve 358::NANTUCKET data
# Retrieve 359::NAZE data
# Retrieve 360::NEMURO data
# Retrieve 361::NEW NORFOLK data
# Retrieve 362::NGAMA data
# Retrieve 363::NGUKURR data
# ngukurr could not found weather info <Error>
# Retrieve 364::NICHINAN data
# Retrieve 365::NICOYA data
# Retrieve 366::NIKOLAYEVKA data
# Retrieve 367::NIKOLSKOYE data
# Retrieve 368::NIZHNEYANSK data
# nizhneyansk could not found weather info <Error>
# Retrieve 369::NOLA data
# Retrieve 370::NOME data
# Retrieve 371::NORMAN WELLS data
# Retrieve 372::NORTH PLATTE data
# Retrieve 373::NOUAKCHOTT data
# Retrieve 374::NOUMEA data
# Retrieve 375::NOVOURALSK data
# Retrieve 376::NUROTA data
# Retrieve 377::NUUK data
# Retrieve 378::NYNASHAMN data
# Retrieve 379::NYROB data
# Retrieve 380::OCAMPO data
# Retrieve 381::ODWEYNE data
# Retrieve 382::OKHOTSK data
# Retrieve 383::OLA data
# Retrieve 384::OLAFSVIK data
# Retrieve 385::OLARI data
# Retrieve 386::OLAVARRIA data
# Retrieve 387::ONOKHOY data
# Retrieve 388::OSORNO data
# Retrieve 389::OSTROVNOY data
# Retrieve 390::OTJIMBINGWE data
# Retrieve 391::OWANDO data
# Retrieve 392::OYTAL data
# Retrieve 393::OZU data
# Retrieve 394::PACHINO data
# Retrieve 395::PACIFIC GROVE data
# Retrieve 396::PAFOS data
# Retrieve 397::PAITA data
# Retrieve 398::PALABUHANRATU data
# palabuhanratu could not found weather info <Error>
# Retrieve 399::PALAIKASTRON data
# Retrieve 400::PALANA data
# Retrieve 401::PALMER data
# Retrieve 402::PANGNIRTUNG data
# Retrieve 403::PANSOY data
# Retrieve 404::PARSABAD data
# Retrieve 405::PASIGHAT data
# Retrieve 406::PASTAVY data
# Retrieve 407::PAYO data
# Retrieve 408::PENICHE data
# Retrieve 409::PETALCINGO data
# Retrieve 410::PETALUMA data
# Retrieve 411::PETROVSK-ZABAYKALSKIY data
# Retrieve 412::PEVEK data
# Retrieve 413::PIRIPIRI data
# Retrieve 414::PISCO data
# Retrieve 415::PITIMBU data
# Retrieve 416::PLETTENBERG BAY data
# Retrieve 417::POCHUTLA data
# Retrieve 418::PODDORYE data
# Retrieve 419::POLSON data
# Retrieve 420::PONAZYREVO data
# Retrieve 421::PONNANI data
# Retrieve 422::PONTA DELGADA data
# Retrieve 423::PONTA DO SOL data
# Retrieve 424::POPLAR BLUFF data
# Retrieve 425::PORT ALFRED data
# Retrieve 426::PORT AUGUSTA data
# Retrieve 427::PORT BLAIR data
# Retrieve 428::PORT ELIZABETH data
# Retrieve 429::PORT HARDY data
# Retrieve 430::PORT HEDLAND data
# Retrieve 431::PORT KEATS data
# Retrieve 432::PORT MACQUARIE data
# Retrieve 433::PORT-GENTIL data
# Retrieve 434::PORTO TORRES data
# Retrieve 435::PRADO data
# Retrieve 436::PRAIA DA VITORIA data
# Retrieve 437::PRAINHA data
# Retrieve 438::PROVIDENIYA data
# Retrieve 439::PUERTO AYACUCHO data
# Retrieve 440::PUERTO AYORA data
# Retrieve 441::PUERTO LEGUIZAMO data
# Retrieve 442::PUNTA ARENAS data
# Retrieve 443::PURO data
# Retrieve 444::QAANAAQ data
# Retrieve 445::QALYUB data
# Retrieve 446::QAQORTOQ data
# Retrieve 447::QINGAN data
# qingan could not found weather info <Error>
# Retrieve 448::RACA data
# Retrieve 449::RAJAPALAIYAM data
# Retrieve 450::RANONG data
# Retrieve 451::RAPID VALLEY data
# Retrieve 452::REXBURG data
# Retrieve 453::RIBEIRA GRANDE data
# Retrieve 454::RICHMOND data
# Retrieve 455::RIKITEA data
# Retrieve 456::RINCON data
# Retrieve 457::RIO GALLEGOS data
# Retrieve 458::RIYADH data
# Retrieve 459::ROAD TOWN data
# Retrieve 460::ROALD data
# Retrieve 461::ROCHA data
# Retrieve 462::RODRIGUES ALVES data
# Retrieve 463::ROLIM DE MOURA data
# rolim de moura could not found weather info <Error>
# Retrieve 464::RONNEBY data
# Retrieve 465::RORVIK data
# Retrieve 466::SABANCUY data
# Retrieve 467::SABZEVAR data
# Retrieve 468::SAHRAK data
# sahrak could not found weather info <Error>
# Retrieve 469::SAINT ANTHONY data
# Retrieve 470::SAINT GEORGE data
# Retrieve 471::SAINT-AUGUSTIN data
# Retrieve 472::SAINT-JOSEPH data
# Retrieve 473::SAINT-PAUL data
# Retrieve 474::SAINT-PHILIPPE data
# Retrieve 475::SAKAKAH data
# Retrieve 476::SALALAH data
# Retrieve 477::SALDANHA data
# Retrieve 478::SALME data
# Retrieve 479::SAMBAVA data
# Retrieve 480::SAMUSU data
# samusu could not found weather info <Error>
# Retrieve 481::SAN ANDRES data
# Retrieve 482::SAN CRISTOBAL data
# Retrieve 483::SAN JOSE data
# Retrieve 484::SAN LUIS data
# Retrieve 485::SAN PATRICIO data
# Retrieve 486::SAN QUINTIN data
# Retrieve 487::SAN RAFAEL data
# Retrieve 488::SAN RAFAEL DEL SUR data
# Retrieve 489::SAN REMIGIO data
# Retrieve 490::SANDWICK data
# Retrieve 491::SANMENXIA data
# Retrieve 492::SANTA CATALINA data
# Retrieve 493::SANTA CRUZ data
# Retrieve 494::SANTA CRUZ DE TENERIFE data
# Retrieve 495::SANTA ISABEL data
# Retrieve 496::SANTA ISABEL DO RIO NEGRO data
# Retrieve 497::SANTA VITORIA DO PALMAR data
# Retrieve 498::SAO FILIPE data
# Retrieve 499::SAO JOAO DA BARRA data
# Retrieve 500::SAO JOSE DA COROA GRANDE data
# Retrieve 501::SASKYLAKH data
# Retrieve 502::SAVONLINNA data
# Retrieve 503::SENTYABRSKIY data
# sentyabrskiy could not found weather info <Error>
# Retrieve 504::SEOUL data
# Retrieve 505::SEPT-ILES data
# Retrieve 506::SEVERO-KURILSK data
# Retrieve 507::SHENJIAMEN data
# Retrieve 508::SHIELI data
# Retrieve 509::SHIMODA data
# Retrieve 510::SHINGU data
# Retrieve 511::SHITANJING data
# Retrieve 512::SIKASSO data
# Retrieve 513::SINOR data
# Retrieve 514::SIOUX LOOKOUT data
# Retrieve 515::SITKA data
# Retrieve 516::SKIBBEREEN data
# Retrieve 517::SKJERVOY data
# Retrieve 518::SKWIERZYNA data
# Retrieve 519::SOLA data
# Retrieve 520::SOMPETA data
# Retrieve 521::SORLAND data
# Retrieve 522::SOUILLAC data
# Retrieve 523::SOYO data
# Retrieve 524::SREDNEKOLYMSK data
# Retrieve 525::SUKUMO data
# Retrieve 526::SUMBAWA data
# sumbawa could not found weather info <Error>
# Retrieve 527::SUNGAIPENUH data
# Retrieve 528::SUSEHRI data
# Retrieve 529::SVETLAYA data
# Retrieve 530::TABUK data
# Retrieve 531::TALARA data
# Retrieve 532::TALDAN data
# Retrieve 533::TALNAKH data
# Retrieve 534::TALTAL data
# Retrieve 535::TAMANDARE data
# Retrieve 536::TANGIER data
# Retrieve 537::TAOLANARO data
# taolanaro could not found weather info <Error>
# Retrieve 538::TASIILAQ data
# Retrieve 539::TATEYAMA data
# Retrieve 540::TAUTIRA data
# Retrieve 541::TE ANAU data
# Retrieve 542::TEAHUPOO data
# Retrieve 543::TECPAN data
# Retrieve 544::TEGUISE data
# Retrieve 545::TESSALIT data
# Retrieve 546::TESSAOUA data
# Retrieve 547::THAI BINH data
# Retrieve 548::THE PAS data
# Retrieve 549::THINADHOO data
# Retrieve 550::THOMPSON data
# Retrieve 551::TIKSI data
# Retrieve 552::TINGRELA data
# tingrela could not found weather info <Error>
# Retrieve 553::TOBIAS BARRETO data
# Retrieve 554::TOCACHE data
# Retrieve 555::TOCOPILLA data
# Retrieve 556::TORBAY data
# Retrieve 557::TOUROS data
# Retrieve 558::TSAGAN AMAN data
# Retrieve 559::TSARATANANA data
# Retrieve 560::TSIHOMBE data
# tsihombe could not found weather info <Error>
# Retrieve 561::TUAL data
# Retrieve 562::TUATAPERE data
# Retrieve 563::TUBINSKIY data
# Retrieve 564::TUGGURT data
# tuggurt could not found weather info <Error>
# Retrieve 565::TUKTOYAKTUK data
# Retrieve 566::TUMANNYY data
# tumannyy could not found weather info <Error>
# Retrieve 567::TUNDURU data
# tunduru could not found weather info <Error>
# Retrieve 568::TUNGAWAN data
# Retrieve 569::TURAN data
# Retrieve 570::TURTKUL data
# turtkul could not found weather info <Error>
# Retrieve 571::TURUKHANSK data
# Retrieve 572::ULMA data
# Retrieve 573::UMM KADDADAH data
# Retrieve 574::UMM LAJJ data
# Retrieve 575::UMZIMVUBU data
# umzimvubu could not found weather info <Error>
# Retrieve 576::UPERNAVIK data
# Retrieve 577::URUMQI data
# Retrieve 578::URUSHA data
# Retrieve 579::URUZGAN data
# Retrieve 580::USHUAIA data
# Retrieve 581::UST-TSILMA data
# Retrieve 582::VAINI data
# Retrieve 583::VAITUPU data
# vaitupu could not found weather info <Error>
# Retrieve 584::VALPARAISO data
# Retrieve 585::VAO data
# Retrieve 586::VASTERVIK data
# vastervik could not found weather info <Error>
# Retrieve 587::VEERE data
# Retrieve 588::VENKATAGIRI data
# Retrieve 589::VERKHOYANSK data
# Retrieve 590::VESTMANNAEYJAR data
# Retrieve 591::VICTORIA data
# Retrieve 592::VILA FRANCA DO CAMPO data
# Retrieve 593::VILA VELHA data
# Retrieve 594::WADDAN data
# Retrieve 595::WAIPAWA data
# Retrieve 596::WAJID data
# Retrieve 597::WALVIS BAY data
# Retrieve 598::WARQLA data
# warqla could not found weather info <Error>
# Retrieve 599::WATTEGAMA data
# Retrieve 600::WAUPUN data
# Retrieve 601::WAYNESVILLE data
# Retrieve 602::WHITEHORSE data
# Retrieve 603::WULANHAOTE data
# wulanhaote could not found weather info <Error>
# Retrieve 604::XINQING data
# Retrieve 605::YABLONOVO data
# Retrieve 606::YAR-SALE data
# Retrieve 607::YARADA data
# Retrieve 608::YELLOWKNIFE data
# Retrieve 609::YENAGOA data
# Retrieve 610::YINING data
# Retrieve 611::YIROL data
# yirol could not found weather info <Error>
# Retrieve 612::YPANE data
# Retrieve 613::YUANCHENG data
# Retrieve 614::YULARA data
# Retrieve 615::ZANJAN data
# Retrieve 616::ZARAZA data
# Retrieve 617::ZAVETNOYE data
# Retrieve 618::ZEYA data
# Retrieve 619::ZHANAOZEN data
# Retrieve 620::ZHANGJIAKOU data
# Retrieve 621::ZHIGANSK data
# Retrieve 622::ZYRYANKA data
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 565

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Format data display Rain with 3 significant decimal and Snow with no significant decimal
#city_data_df["Rain inches(last 3hrs)"]=city_data_df["Rain inches(last 3hrs)"].map("{:.3f}".format)
#city_data_df["Snow inches(last 3hrs)"]=city_data_df["Snow inches(last 3hrs)"].map("{:.0f}".format)
# Top 10 row data
#city_data_df.style.set_caption("The City Weather Data"+time.strftime('%x'))
city_data_df.head(10)
# Out:
#           City Country                 Date    Lat     Lng  Max Temp  \
# 0  Abong Mbang      CM  2020-02-18 05:32:23   3.98   13.18     68.97
# 1     Abonnema      NG  2020-02-18 05:32:23   4.71    6.79     78.69
# 2    Abu Dhabi      AE  2020-02-18 05:30:22  24.47   54.37     69.80
# 3       Acarau      BR  2020-02-18 05:32:24  -2.89  -40.12     74.91
# 4    Achacachi      BO  2020-02-18 05:32:24 -16.05  -68.68     34.05
# 5        Afsin      TR  2020-02-18 05:32:25  38.25   36.91     18.79
# 6      Ahipara      NZ  2020-02-18 05:32:25 -35.17  173.17     71.92
# 7        Airai      TL  2020-02-18 05:32:25  -8.93  125.41     80.20
# 8      Aklavik      CA  2020-02-18 05:32:25  68.22 -135.01    -23.80
# 9       Albany      US  2020-02-18 05:29:18  42.60  -73.97     27.00
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        93          41        3.29    scattered clouds
# 1        88          78        2.51       broken clouds
# 2        49          72        9.17       broken clouds
# 3        94          92        2.04     overcast clouds
# 4        80         100        0.67     overcast clouds
# 5        90          35        2.53    scattered clouds
# 6        73          20        4.54          few clouds
# 7        69          41        4.90          light rain
# 8        74           5        5.82           clear sky
# 9        58          90        4.70     overcast clouds
#
#    Rain inches(last 3hrs)  Snow inches(last 3hrs)
# 0                    0.00                     0.0
# 1                    0.00                     0.0
# 2                    0.00                     0.0
# 3                    0.00                     0.0
# 4                    0.00                     0.0
# 5                    0.00                     0.0
# 6                    0.00                     0.0
# 7                    2.81                     0.0
# 8                    0.00                     0.0
# 9                    0.00                     0.0

# %% [markdown]
# ***Answer this question using Pandas methods: How many cities have recorded rainfall or snow?***

# %%
# Query and count cities either rain or snow
city_data_df.loc[(pd.to_numeric(city_data_df["Rain inches(last 3hrs)"])>0)|\
                 (pd.to_numeric(city_data_df["Snow inches(last 3hrs)"])>0),"City"].count()
# Out:
# 83

# %%
# Export the City_Data into a CSV without index.
city_data_df.to_csv("weather_data/WeatherPy_challenge.csv",index=False)
